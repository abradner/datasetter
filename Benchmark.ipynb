# %%
from app.algolia_benchmark import benchmark_searches, do_benchmark
from app.algolia_client import Client

import matplotlib.pyplot as plt

# %%
client = Client()

# %%
df = benchmark_searches(client)
# Out:
# INFO 86700 4557250048 2021-07-01 11:03:52,066 root.do_benchmark:39 - BENCHMARKING
# INFO 86700 4557250048 2021-07-01 11:03:52,109 root.do_benchmark:51 - BENCH: WARMING UP
# INFO 86700 4557250048 2021-07-01 11:03:52,271 root.do_benchmark:58 - warmup 0 - 0.160454s
# INFO 86700 4557250048 2021-07-01 11:03:52,343 root.do_benchmark:58 - warmup 1 - 0.071645s
# INFO 86700 4557250048 2021-07-01 11:03:52,412 root.do_benchmark:58 - warmup 2 - 0.068155s
# INFO 86700 4557250048 2021-07-01 11:03:52,481 root.do_benchmark:58 - warmup 3 - 0.067824s
# INFO 86700 4557250048 2021-07-01 11:03:52,549 root.do_benchmark:58 - warmup 4 - 0.067210s
# INFO 86700 4557250048 2021-07-01 11:03:52,550 root.do_benchmark:61 - BENCH: BOUNDARY FILTERS
# INFO 86700 4557250048 2021-07-01 11:03:52,678 root.do_benchmark:75 - point: (-33.883754,151.171661) - 0.127417s
# INFO 86700 4557250048 2021-07-01 11:03:52,771 root.do_benchmark:75 - point: (-33.810759,150.912796) - 0.092211s
# ...

# %%
df
# Out:
#     boundary_times  boundary_processing_times  boundary_hits  geohash_times  \
# 0         0.127417                          6           2210       0.087378
# 1         0.092211                          7           1836       0.087072
# 2         0.090466                          7           2167       0.137436
# 3         0.091051                          7           2153       0.089001
# 4         0.142142                          7           2042       0.091313
# ..             ...                        ...            ...            ...
# 95        0.092718                          7           1951       0.093832
# 96        0.094565                          8           1992       0.088343
# 97        0.087984                          7           2056       0.087082
# 98        0.145894                          7           1919       0.146895
# 99        0.090091                          7           1711       0.087669
#
#     geohash_processing_times  geohash_hits
# ...

# %%
df[['boundary_times','geohash_times']].plot(figsize=(12, 9))
# Out:
# <AxesSubplot:>

# %%
df[['boundary_processing_times','geohash_processing_times']].plot(figsize=(12, 9));

# %%
df[['boundary_hits','geohash_hits']].plot(figsize=(12, 9));
