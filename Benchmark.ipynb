# %%
from app.algolia_benchmark import benchmark_searches, do_benchmark
from app.algolia_client import Client

import matplotlib.pyplot as plt

# %%
client = Client()

# %%
df = benchmark_searches(client)
# Out:
# INFO 15162 4574899712 2021-07-19 12:47:30,322 root.do_benchmark:39 - BENCHMARKING
# INFO 15162 4574899712 2021-07-19 12:47:30,371 root.do_benchmark:51 - BENCH: WARMING UP
# INFO 15162 4574899712 2021-07-19 12:47:30,520 root.do_benchmark:58 - warmup 0 - 0.147538s
# INFO 15162 4574899712 2021-07-19 12:47:30,593 root.do_benchmark:58 - warmup 1 - 0.072614s
# INFO 15162 4574899712 2021-07-19 12:47:30,664 root.do_benchmark:58 - warmup 2 - 0.070563s
# INFO 15162 4574899712 2021-07-19 12:47:30,736 root.do_benchmark:58 - warmup 3 - 0.071173s
# INFO 15162 4574899712 2021-07-19 12:47:30,809 root.do_benchmark:58 - warmup 4 - 0.071727s
# INFO 15162 4574899712 2021-07-19 12:47:30,809 root.do_benchmark:61 - BENCH: BOUNDARY FILTERS
# INFO 15162 4574899712 2021-07-19 12:47:31,002 root.do_benchmark:75 - point: (-33.709146,151.286331) - 0.192027s
# INFO 15162 4574899712 2021-07-19 12:47:31,167 root.do_benchmark:75 - point: (-33.628570,151.327530) - 0.164091s
# ...

# %%
df
# Out:
#     boundary_times  boundary_processing_times  boundary_hits  geohash_times  \
# 0         0.192027                         17           1623       0.101233
# 1         0.164091                         20           1351       0.207456
# 2         0.111702                         14           1708       0.103040
# 3         0.148818                         13           1975       0.096914
# 4         0.094334                         11           2199       0.092203
# ..             ...                        ...            ...            ...
# 95        0.098498                         14           2006       0.099930
# 96        0.073725                          6           1728       0.085922
# 97        0.089578                          7           2150       0.143034
# 98        0.143877                          7           2094       0.094543
# 99        0.090868                          7           2162       0.082046
#
#     geohash_processing_times  geohash_hits
# ...

# %%
df[['boundary_times','geohash_times']].plot(figsize=(16, 9))
# Out:
# <AxesSubplot:>

# %%
df[['boundary_processing_times','geohash_processing_times']].plot(figsize=(16, 9));

# %%
df[['boundary_hits','geohash_hits']].plot(figsize=(16, 9));
