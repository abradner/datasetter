# %%
import pandas as pd
from app.runner import RAW_DATASET_FILE
from app.data import DATASETS_DIR, load_dataset

# %%
df = load_dataset()
# Out:
# INFO 58802 4377714176 2021-06-30 21:46:44,754 root._fetch_data:35 - Fetching /Users/alexbradner/code/datasetter/app/datasets/dataset.sql
# INFO 58802 4377714176 2021-06-30 21:46:44,757 snowflake.connector.connection.__init__:257 - Snowflake Connector for Python Version: 2.4.6, Python Version: 3.9.5, Platform: macOS-11.4-x86_64-i386-64bit
# INFO 58802 4377714176 2021-06-30 21:46:44,758 snowflake.connector.connection.__config:868 - This connection is in OCSP Fail Open Mode. TLS Certificates would be checked for validity and revocation status. Any other Certificate Revocation related exceptions or OCSP Responder failures would be disregarded in favor of connectivity.
# INFO 58802 4377714176 2021-06-30 21:46:44,759 snowflake.connector.connection.__config:886 - Setting use_openssl_only mode to False
# INFO 58802 4377714176 2021-06-30 21:46:45,505 snowflake.connector.cursor.execute:637 - query: [USE role PROD_FULL_READER]
# ...

# %%
df
# Out:
#                                          id issuer_id  \
# 0      9bd80fd8-deb0-4e83-9360-742b41c98637   2636318
# 1      432f20a7-9ea5-481b-a2c3-2cfee4d552bc   1852374
# 2      ee1d9071-16b7-448d-8d2b-626fb8db7817    104594
# 3      6595d8ee-c559-4173-8c7f-7cc923810046   4051965
# 4      e7ed0da9-8e6d-4a3d-b86b-981e56f90c55   3813904
# ...                                     ...       ...
# 10147  fe279e76-1f90-4c06-923a-ec5ac8c65ffd   2384375
# 10148  f0ea74eb-8353-4e91-9b2d-88e8d6692e0b    955030
# 10149  3e7a258a-d772-4cb8-bbee-8399cc458c30   4228378
# 10150  f6d98565-d8a3-4cf6-b7a9-c83bff1430b5   3884671
# 10151  22a43480-2ff0-4ffd-bad0-0a5f131545d4   4688581
#
#                                                   title  \
# 0                             Professional lawn mowing
# 1            Passanger vehicle and truck tyre services.
# 2                            Cctv  system installations
# 3                       Hairdresser & Beauty Treatment.
# ...
